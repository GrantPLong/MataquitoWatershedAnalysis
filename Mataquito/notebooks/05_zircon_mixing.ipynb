# %% [markdown]
# # DetritalPy Mixing code for the Mataquito River: Every Scenario

# %% [markdown]
# ## detritalPy-mix
# #### Glenn R. Sharman and Sam A. Johnstone
# #### Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty
# #### Version 0.1 (Beta)
# ##### Updated Feb 9, 2024
# ##### Requires detritalPy v1.4.0 or later
# ##### This is a Beta release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.
# ##### If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044)

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import os
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).
#
# Change parent and child list to see mixing results for CT-1 through CT-11

# %%
dataToLoad = ['../data/geochronology/zircon_upb/CT-1-11_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

""" 
Plug in the two / three parents that you want followed by all the children associated with all the parents. The options below are set up for easy use.
You will choose what parents you want and the associated child. Comment in/out whichever you want
"""
# Child options where parent list is CT-7, CT-1
#parent_list = ['CT-7', 'CT-1']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Child options where parent list is CT-5, CT-6
#parent_list = ['CT-5', 'CT-6']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Parent list options where Child is CT-2
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-2']

# Parent list options where Child is CT-9
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
parent_list = ['CT-2', 'CT-3']
child_list = ['CT-9']

# Three to one mixtures
    # Parent list options where Child is CT-2
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-2']

    # Parent list options where Child is CT-9
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-9']

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 2 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.18517279118094554
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Completed mixing children.
# Time elapsed: 0.081 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-9
# Best-fit vmax : 0.185
# Mixing coefficients
# --- CT-2 : 0.999
# --- CT-3 : 0.001

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 10000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-9 ( 1 of 1 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 8.328 minutes remaining
# 0.1 % completed, 0.008 minutes elapsed, 6.825 minutes remaining
# 0.2 % completed, 0.013 minutes elapsed, 6.07 minutes remaining
# 0.3 % completed, 0.018 minutes elapsed, 5.829 minutes remaining
# 0.4 % completed, 0.023 minutes elapsed, 5.673 minutes remaining
# 0.5 % completed, 0.029 minutes elapsed, 5.593 minutes remaining
# 0.6 % completed, 0.035 minutes elapsed, 5.734 minutes remaining
# 0.7 % completed, 0.044 minutes elapsed, 6.141 minutes remaining
# 0.8 % completed, 0.055 minutes elapsed, 6.743 minutes remaining
# 0.9 % completed, 0.068 minutes elapsed, 7.434 minutes remaining
# 1.0 % completed, 0.079 minutes elapsed, 7.786 minutes remaining
# 1.1 % completed, 0.093 minutes elapsed, 8.304 minutes remaining
# 1.2 % completed, 0.105 minutes elapsed, 8.557 minutes remaining
# 1.3 % completed, 0.115 minutes elapsed, 8.683 minutes remaining
# 1.4 % completed, 0.126 minutes elapsed, 8.796 minutes remaining
# 1.5 % completed, 0.138 minutes elapsed, 9.02 minutes remaining
# 1.6 % completed, 0.151 minutes elapsed, 9.216 minutes remaining
# 1.7 % completed, 0.163 minutes elapsed, 9.395 minutes remaining
# 64.1 % completed, 3.422 minutes elapsed, 1.916 minutes remaining
# 64.2 % completed, 3.427 minutes elapsed, 1.911 minutes remaining
# 64.3 % completed, 3.432 minutes elapsed, 1.905 minutes remaining
# 64.4 % completed, 3.437 minutes elapsed, 1.9 minutes remaining
# 64.5 % completed, 3.442 minutes elapsed, 1.894 minutes remaining
# 64.6 % completed, 3.448 minutes elapsed, 1.889 minutes remaining
# 64.7 % completed, 3.454 minutes elapsed, 1.884 minutes remaining
# 64.8 % completed, 3.459 minutes elapsed, 1.879 minutes remaining
# 64.9 % completed, 3.464 minutes elapsed, 1.873 minutes remaining
# 65.0 % completed, 3.469 minutes elapsed, 1.868 minutes remaining
# 65.1 % completed, 3.474 minutes elapsed, 1.862 minutes remaining
# 65.2 % completed, 3.479 minutes elapsed, 1.857 minutes remaining
# 65.3 % completed, 3.484 minutes elapsed, 1.851 minutes remaining
# 65.4 % completed, 3.489 minutes elapsed, 1.846 minutes remaining
# 65.5 % completed, 3.494 minutes elapsed, 1.84 minutes remaining
# 65.6 % completed, 3.499 minutes elapsed, 1.835 minutes remaining
# 65.7 % completed, 3.504 minutes elapsed, 1.829 minutes remaining
# 65.8 % completed, 3.509 minutes elapsed, 1.824 minutes remaining
# 65.9 % completed, 3.514 minutes elapsed, 1.818 minutes remaining
# 66.0 % completed, 3.519 minutes elapsed, 1.813 minutes remaining
# 66.1 % completed, 3.525 minutes elapsed, 1.808 minutes remaining
# 66.2 % completed, 3.53 minutes elapsed, 1.802 minutes remaining
# 66.3 % completed, 3.536 minutes elapsed, 1.797 minutes remaining
# 66.4 % completed, 3.541 minutes elapsed, 1.791 minutes remaining
# 66.5 % completed, 3.546 minutes elapsed, 1.786 minutes remaining
# 66.6 % completed, 3.551 minutes elapsed, 1.78 minutes remaining
# 66.7 % completed, 3.557 minutes elapsed, 1.776 minutes remaining
# 66.8 % completed, 3.562 minutes elapsed, 1.77 minutes remaining
# 66.9 % completed, 3.568 minutes elapsed, 1.765 minutes remaining
# 67.0 % completed, 3.573 minutes elapsed, 1.76 minutes remaining
# 67.1 % completed, 3.578 minutes elapsed, 1.754 minutes remaining
# 67.2 % completed, 3.583 minutes elapsed, 1.749 minutes remaining
# 67.3 % completed, 3.588 minutes elapsed, 1.743 minutes remaining
# 67.4 % completed, 3.593 minutes elapsed, 1.738 minutes remaining
# 67.5 % completed, 3.598 minutes elapsed, 1.732 minutes remaining
# 67.6 % completed, 3.603 minutes elapsed, 1.727 minutes remaining
# 67.7 % completed, 3.608 minutes elapsed, 1.721 minutes remaining
# 67.8 % completed, 3.613 minutes elapsed, 1.716 minutes remaining
# 67.9 % completed, 3.618 minutes elapsed, 1.71 minutes remaining
# 68.0 % completed, 3.623 minutes elapsed, 1.705 minutes remaining
# 68.1 % completed, 3.628 minutes elapsed, 1.699 minutes remaining
# 68.2 % completed, 3.633 minutes elapsed, 1.694 minutes remaining
# 68.3 % completed, 3.638 minutes elapsed, 1.688 minutes remaining
# 68.4 % completed, 3.643 minutes elapsed, 1.683 minutes remaining
# 68.5 % completed, 3.648 minutes elapsed, 1.677 minutes remaining
# 68.6 % completed, 3.652 minutes elapsed, 1.672 minutes remaining
# 68.7 % completed, 3.658 minutes elapsed, 1.666 minutes remaining
# 68.8 % completed, 3.662 minutes elapsed, 1.661 minutes remaining
# 68.9 % completed, 3.667 minutes elapsed, 1.655 minutes remaining
# 69.0 % completed, 3.672 minutes elapsed, 1.65 minutes remaining
# 69.1 % completed, 3.677 minutes elapsed, 1.644 minutes remaining
# 69.2 % completed, 3.682 minutes elapsed, 1.639 minutes remaining
# 69.3 % completed, 3.687 minutes elapsed, 1.633 minutes remaining
# 69.4 % completed, 3.692 minutes elapsed, 1.628 minutes remaining
# 69.5 % completed, 3.697 minutes elapsed, 1.622 minutes remaining
# 69.6 % completed, 3.702 minutes elapsed, 1.617 minutes remaining
# 69.7 % completed, 3.707 minutes elapsed, 1.611 minutes remaining
# 69.8 % completed, 3.712 minutes elapsed, 1.606 minutes remaining
# 69.9 % completed, 3.717 minutes elapsed, 1.6 minutes remaining
# 70.0 % completed, 3.722 minutes elapsed, 1.595 minutes remaining
# 70.1 % completed, 3.727 minutes elapsed, 1.589 minutes remaining
# 70.2 % completed, 3.732 minutes elapsed, 1.584 minutes remaining
# 70.3 % completed, 3.737 minutes elapsed, 1.578 minutes remaining
# 70.4 % completed, 3.742 minutes elapsed, 1.573 minutes remaining
# 70.5 % completed, 3.747 minutes elapsed, 1.568 minutes remaining
# 70.6 % completed, 3.752 minutes elapsed, 1.562 minutes remaining
# 70.7 % completed, 3.757 minutes elapsed, 1.557 minutes remaining
# 70.8 % completed, 3.762 minutes elapsed, 1.551 minutes remaining
# 70.9 % completed, 3.766 minutes elapsed, 1.546 minutes remaining
# 71.0 % completed, 3.771 minutes elapsed, 1.54 minutes remaining
# 71.1 % completed, 3.776 minutes elapsed, 1.535 minutes remaining
# 71.2 % completed, 3.781 minutes elapsed, 1.529 minutes remaining
# 71.3 % completed, 3.786 minutes elapsed, 1.524 minutes remaining
# 71.4 % completed, 3.793 minutes elapsed, 1.519 minutes remaining
# 71.5 % completed, 3.799 minutes elapsed, 1.514 minutes remaining
# 71.6 % completed, 3.804 minutes elapsed, 1.508 minutes remaining
# 71.7 % completed, 3.809 minutes elapsed, 1.503 minutes remaining
# 71.8 % completed, 3.814 minutes elapsed, 1.498 minutes remaining
# 71.9 % completed, 3.819 minutes elapsed, 1.492 minutes remaining
# 72.0 % completed, 3.824 minutes elapsed, 1.487 minutes remaining
# 72.1 % completed, 3.829 minutes elapsed, 1.481 minutes remaining
# 72.2 % completed, 3.834 minutes elapsed, 1.476 minutes remaining
# 72.3 % completed, 3.839 minutes elapsed, 1.47 minutes remaining
# 72.4 % completed, 3.844 minutes elapsed, 1.465 minutes remaining
# 72.5 % completed, 3.849 minutes elapsed, 1.46 minutes remaining
# 72.6 % completed, 3.854 minutes elapsed, 1.454 minutes remaining
# 72.7 % completed, 3.859 minutes elapsed, 1.449 minutes remaining
# 72.8 % completed, 3.864 minutes elapsed, 1.443 minutes remaining
# 72.9 % completed, 3.869 minutes elapsed, 1.438 minutes remaining
# 83.2 % completed, 4.388 minutes elapsed, 0.886 minutes remaining
# 83.3 % completed, 4.393 minutes elapsed, 0.881 minutes remaining
# 83.4 % completed, 4.398 minutes elapsed, 0.875 minutes remaining
# 83.5 % completed, 4.403 minutes elapsed, 0.87 minutes remaining
# 83.6 % completed, 4.408 minutes elapsed, 0.865 minutes remaining
# 83.7 % completed, 4.413 minutes elapsed, 0.859 minutes remaining
# 83.8 % completed, 4.418 minutes elapsed, 0.854 minutes remaining
# 83.9 % completed, 4.423 minutes elapsed, 0.849 minutes remaining
# 84.0 % completed, 4.429 minutes elapsed, 0.843 minutes remaining
# 84.1 % completed, 4.434 minutes elapsed, 0.838 minutes remaining
# 84.2 % completed, 4.439 minutes elapsed, 0.833 minutes remaining
# 84.3 % completed, 4.444 minutes elapsed, 0.828 minutes remaining
# 84.4 % completed, 4.449 minutes elapsed, 0.822 minutes remaining
# 84.5 % completed, 4.454 minutes elapsed, 0.817 minutes remaining
# 84.6 % completed, 4.459 minutes elapsed, 0.812 minutes remaining
# 84.7 % completed, 4.465 minutes elapsed, 0.807 minutes remaining
# 84.8 % completed, 4.47 minutes elapsed, 0.801 minutes remaining
# 84.9 % completed, 4.475 minutes elapsed, 0.796 minutes remaining
# 85.0 % completed, 4.48 minutes elapsed, 0.791 minutes remaining
# 85.1 % completed, 4.485 minutes elapsed, 0.785 minutes remaining
# 85.2 % completed, 4.49 minutes elapsed, 0.78 minutes remaining
# 85.3 % completed, 4.495 minutes elapsed, 0.775 minutes remaining
# 85.4 % completed, 4.5 minutes elapsed, 0.769 minutes remaining
# 85.5 % completed, 4.505 minutes elapsed, 0.764 minutes remaining
# 85.6 % completed, 4.51 minutes elapsed, 0.759 minutes remaining
# 85.7 % completed, 4.515 minutes elapsed, 0.753 minutes remaining
# 85.8 % completed, 4.521 minutes elapsed, 0.748 minutes remaining
# 85.9 % completed, 4.526 minutes elapsed, 0.743 minutes remaining
# 86.0 % completed, 4.531 minutes elapsed, 0.737 minutes remaining
# 86.1 % completed, 4.536 minutes elapsed, 0.732 minutes remaining
# 86.2 % completed, 4.541 minutes elapsed, 0.727 minutes remaining
# 86.3 % completed, 4.546 minutes elapsed, 0.722 minutes remaining
# 86.4 % completed, 4.551 minutes elapsed, 0.716 minutes remaining
# 86.5 % completed, 4.557 minutes elapsed, 0.711 minutes remaining
# 86.6 % completed, 4.563 minutes elapsed, 0.706 minutes remaining
# 86.7 % completed, 4.568 minutes elapsed, 0.701 minutes remaining
# 86.8 % completed, 4.573 minutes elapsed, 0.695 minutes remaining
# 86.9 % completed, 4.578 minutes elapsed, 0.69 minutes remaining
# 87.0 % completed, 4.583 minutes elapsed, 0.685 minutes remaining
# 87.1 % completed, 4.588 minutes elapsed, 0.679 minutes remaining
# 87.2 % completed, 4.593 minutes elapsed, 0.674 minutes remaining
# 87.3 % completed, 4.598 minutes elapsed, 0.669 minutes remaining
# 87.4 % completed, 4.603 minutes elapsed, 0.664 minutes remaining
# 87.5 % completed, 4.608 minutes elapsed, 0.658 minutes remaining
# 87.6 % completed, 4.613 minutes elapsed, 0.653 minutes remaining
# 87.7 % completed, 4.618 minutes elapsed, 0.648 minutes remaining
# 87.8 % completed, 4.623 minutes elapsed, 0.642 minutes remaining
# 87.9 % completed, 4.628 minutes elapsed, 0.637 minutes remaining
# 88.0 % completed, 4.633 minutes elapsed, 0.632 minutes remaining
# 88.1 % completed, 4.638 minutes elapsed, 0.626 minutes remaining
# 88.2 % completed, 4.643 minutes elapsed, 0.621 minutes remaining
# 88.3 % completed, 4.648 minutes elapsed, 0.616 minutes remaining
# 88.4 % completed, 4.653 minutes elapsed, 0.61 minutes remaining
# 88.5 % completed, 4.658 minutes elapsed, 0.605 minutes remaining
# 88.6 % completed, 4.664 minutes elapsed, 0.6 minutes remaining
# 88.7 % completed, 4.669 minutes elapsed, 0.595 minutes remaining
# 88.8 % completed, 4.674 minutes elapsed, 0.589 minutes remaining
# 88.9 % completed, 4.679 minutes elapsed, 0.584 minutes remaining
# 89.0 % completed, 4.685 minutes elapsed, 0.579 minutes remaining
# 89.1 % completed, 4.69 minutes elapsed, 0.574 minutes remaining
# 89.2 % completed, 4.695 minutes elapsed, 0.568 minutes remaining
# 89.3 % completed, 4.7 minutes elapsed, 0.563 minutes remaining
# 89.4 % completed, 4.706 minutes elapsed, 0.558 minutes remaining
# 89.5 % completed, 4.712 minutes elapsed, 0.553 minutes remaining
# 89.6 % completed, 4.717 minutes elapsed, 0.547 minutes remaining
# 89.7 % completed, 4.722 minutes elapsed, 0.542 minutes remaining
# 89.8 % completed, 4.727 minutes elapsed, 0.537 minutes remaining
# 89.9 % completed, 4.732 minutes elapsed, 0.532 minutes remaining
# 90.0 % completed, 4.738 minutes elapsed, 0.526 minutes remaining
# 90.1 % completed, 4.743 minutes elapsed, 0.521 minutes remaining
# 90.2 % completed, 4.748 minutes elapsed, 0.516 minutes remaining
# 90.3 % completed, 4.754 minutes elapsed, 0.511 minutes remaining
# 90.4 % completed, 4.759 minutes elapsed, 0.505 minutes remaining
# 90.5 % completed, 4.765 minutes elapsed, 0.5 minutes remaining
# 90.6 % completed, 4.771 minutes elapsed, 0.495 minutes remaining
# 90.7 % completed, 4.776 minutes elapsed, 0.49 minutes remaining
# 90.8 % completed, 4.783 minutes elapsed, 0.485 minutes remaining
# 90.9 % completed, 4.788 minutes elapsed, 0.479 minutes remaining
# 91.0 % completed, 4.794 minutes elapsed, 0.474 minutes remaining
# 91.1 % completed, 4.8 minutes elapsed, 0.469 minutes remaining
# 91.2 % completed, 4.805 minutes elapsed, 0.464 minutes remaining
# 91.3 % completed, 4.811 minutes elapsed, 0.458 minutes remaining
# 91.4 % completed, 4.816 minutes elapsed, 0.453 minutes remaining
# 91.5 % completed, 4.821 minutes elapsed, 0.448 minutes remaining
# 91.6 % completed, 4.826 minutes elapsed, 0.443 minutes remaining
# 91.7 % completed, 4.832 minutes elapsed, 0.437 minutes remaining
# 91.8 % completed, 4.837 minutes elapsed, 0.432 minutes remaining
# 91.9 % completed, 4.842 minutes elapsed, 0.427 minutes remaining
# 92.0 % completed, 4.847 minutes elapsed, 0.421 minutes remaining
# 92.1 % completed, 4.852 minutes elapsed, 0.416 minutes remaining
# 92.2 % completed, 4.857 minutes elapsed, 0.411 minutes remaining
# 92.3 % completed, 4.863 minutes elapsed, 0.406 minutes remaining
# 92.4 % completed, 4.869 minutes elapsed, 0.4 minutes remaining
# 92.5 % completed, 4.875 minutes elapsed, 0.395 minutes remaining
# 92.6 % completed, 4.88 minutes elapsed, 0.39 minutes remaining
# 92.7 % completed, 4.885 minutes elapsed, 0.385 minutes remaining
# 92.8 % completed, 4.89 minutes elapsed, 0.379 minutes remaining
# 92.9 % completed, 4.895 minutes elapsed, 0.374 minutes remaining
# 93.0 % completed, 4.9 minutes elapsed, 0.369 minutes remaining
# 93.1 % completed, 4.905 minutes elapsed, 0.363 minutes remaining
# 93.2 % completed, 4.91 minutes elapsed, 0.358 minutes remaining
# 93.3 % completed, 4.915 minutes elapsed, 0.353 minutes remaining
# 93.4 % completed, 4.92 minutes elapsed, 0.348 minutes remaining
# 93.5 % completed, 4.925 minutes elapsed, 0.342 minutes remaining
# 93.6 % completed, 4.93 minutes elapsed, 0.337 minutes remaining
# 93.7 % completed, 4.935 minutes elapsed, 0.332 minutes remaining
# 93.8 % completed, 4.94 minutes elapsed, 0.326 minutes remaining
# 93.9 % completed, 4.944 minutes elapsed, 0.321 minutes remaining
# 94.0 % completed, 4.95 minutes elapsed, 0.316 minutes remaining
# 94.1 % completed, 4.954 minutes elapsed, 0.311 minutes remaining
# 94.2 % completed, 4.959 minutes elapsed, 0.305 minutes remaining
# 94.3 % completed, 4.964 minutes elapsed, 0.3 minutes remaining
# 94.4 % completed, 4.969 minutes elapsed, 0.295 minutes remaining
# 94.5 % completed, 4.974 minutes elapsed, 0.289 minutes remaining
# 94.6 % completed, 4.979 minutes elapsed, 0.284 minutes remaining
# 94.7 % completed, 4.984 minutes elapsed, 0.279 minutes remaining
# 94.8 % completed, 4.989 minutes elapsed, 0.274 minutes remaining
# 94.9 % completed, 4.994 minutes elapsed, 0.268 minutes remaining
# 95.0 % completed, 4.999 minutes elapsed, 0.263 minutes remaining
# 95.1 % completed, 5.004 minutes elapsed, 0.258 minutes remaining
# 95.2 % completed, 5.009 minutes elapsed, 0.253 minutes remaining
# 95.3 % completed, 5.014 minutes elapsed, 0.247 minutes remaining
# 95.4 % completed, 5.019 minutes elapsed, 0.242 minutes remaining
# 95.5 % completed, 5.024 minutes elapsed, 0.237 minutes remaining
# 95.6 % completed, 5.029 minutes elapsed, 0.231 minutes remaining
# 95.7 % completed, 5.034 minutes elapsed, 0.226 minutes remaining
# 95.8 % completed, 5.039 minutes elapsed, 0.221 minutes remaining
# 95.9 % completed, 5.044 minutes elapsed, 0.216 minutes remaining
# 96.0 % completed, 5.049 minutes elapsed, 0.21 minutes remaining
# 96.1 % completed, 5.054 minutes elapsed, 0.205 minutes remaining
# 96.2 % completed, 5.059 minutes elapsed, 0.2 minutes remaining
# 96.3 % completed, 5.064 minutes elapsed, 0.195 minutes remaining
# 96.4 % completed, 5.069 minutes elapsed, 0.189 minutes remaining
# 96.5 % completed, 5.074 minutes elapsed, 0.184 minutes remaining
# 96.6 % completed, 5.079 minutes elapsed, 0.179 minutes remaining
# 96.7 % completed, 5.084 minutes elapsed, 0.173 minutes remaining
# 96.8 % completed, 5.089 minutes elapsed, 0.168 minutes remaining
# 96.9 % completed, 5.094 minutes elapsed, 0.163 minutes remaining
# 97.0 % completed, 5.099 minutes elapsed, 0.158 minutes remaining
# 97.1 % completed, 5.104 minutes elapsed, 0.152 minutes remaining
# 97.2 % completed, 5.109 minutes elapsed, 0.147 minutes remaining
# 97.3 % completed, 5.114 minutes elapsed, 0.142 minutes remaining
# 97.4 % completed, 5.119 minutes elapsed, 0.137 minutes remaining
# 97.5 % completed, 5.124 minutes elapsed, 0.131 minutes remaining
# 97.6 % completed, 5.129 minutes elapsed, 0.126 minutes remaining
# 97.7 % completed, 5.134 minutes elapsed, 0.121 minutes remaining
# 97.8 % completed, 5.138 minutes elapsed, 0.116 minutes remaining
# 97.9 % completed, 5.143 minutes elapsed, 0.11 minutes remaining
# 98.0 % completed, 5.148 minutes elapsed, 0.105 minutes remaining
# 98.1 % completed, 5.153 minutes elapsed, 0.1 minutes remaining
# 98.2 % completed, 5.158 minutes elapsed, 0.095 minutes remaining
# 98.3 % completed, 5.163 minutes elapsed, 0.089 minutes remaining
# 98.4 % completed, 5.168 minutes elapsed, 0.084 minutes remaining
# 98.5 % completed, 5.173 minutes elapsed, 0.079 minutes remaining
# 98.6 % completed, 5.178 minutes elapsed, 0.074 minutes remaining
# 98.7 % completed, 5.183 minutes elapsed, 0.068 minutes remaining
# 98.8 % completed, 5.188 minutes elapsed, 0.063 minutes remaining
# 98.9 % completed, 5.193 minutes elapsed, 0.058 minutes remaining
# 99.0 % completed, 5.198 minutes elapsed, 0.052 minutes remaining
# 99.1 % completed, 5.203 minutes elapsed, 0.047 minutes remaining
# 99.2 % completed, 5.208 minutes elapsed, 0.042 minutes remaining
# 99.3 % completed, 5.213 minutes elapsed, 0.037 minutes remaining
# 99.4 % completed, 5.218 minutes elapsed, 0.031 minutes remaining
# 99.5 % completed, 5.223 minutes elapsed, 0.026 minutes remaining
# 99.6 % completed, 5.228 minutes elapsed, 0.021 minutes remaining
# 99.7 % completed, 5.233 minutes elapsed, 0.016 minutes remaining
# 99.8 % completed, 5.238 minutes elapsed, 0.01 minutes remaining
# 99.9 % completed, 5.243 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %%
#print(mix_coeffs_all)

# %%
print(f"Number of items: {len(mix_coeffs_all[0])}")
print(f"Array shape: {mix_coeffs_all[0].shape}")
# Out:
# Number of items: 10000
# Array shape: (10000, 2)

# %% [markdown]
# ### Export csv file of mix_coeffs_all for use in the zircon fertility analysis

# %%
# Converting the mix_coeffs_all to a 2D array so that we can run all 10,000 pairs of w1 and w2 through to understand the
# distribution through the bootstraping analyses. 
try:
    # Convert list to NumPy array
    array = np.array(mix_coeffs_all)
    # Flatten the array
    flattened_array = array.reshape(-1, array.shape[-1])
    # Determine column names based on the number of coefficients
    num_coeffs = flattened_array.shape[1]
    if num_coeffs == 2:
        column_names = ['Column1', 'Column2']
    elif num_coeffs == 3:
        column_names = ['Column1', 'Column2', 'Column3']
    else:
        # Fallback for other numbers of coefficients
        column_names = [f'Column{i+1}' for i in range(num_coeffs)]
    # Convert to DataFrame
    df = pd.DataFrame(flattened_array, columns=column_names)
    # Save to CSV in a "Spreadsheets" folder
    folder_path = "../results/mixing_coefficients"
    # Change name to current mixture
    filename = "mix_coeffs_all_ct-2_ct-3_to_ct-9.csv"
    # Create folder if it doesn't exist
    os.makedirs(folder_path, exist_ok=True)
    # Create full path and save
    full_path = os.path.join(folder_path, filename)
    df.to_csv(full_path, index=False)
    print("Saved")
    
except Exception as e:
    print(f"Not saved: {e}")
    # Optional: Print array shape for debugging
    if 'array' in locals():
        print(f"Array shape: {array.shape}")
    if 'flattened_array' in locals():
        print(f"Flattened array shape: {flattened_array.shape}")
# Out:
# Saved

# %%
# Plot histograms of all coefficients on same plot to visualize the distributions
plt.figure(figsize=(10, 6))

# Define colors for up to 6 coefficients (extend as needed)
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown']

# Get the number of coefficient columns
num_coeffs = len([col for col in df.columns if col.startswith('Column')])

# Plot histogram for each coefficient
for i in range(num_coeffs):
    col_name = f'Column{i+1}'
    color = colors[i % len(colors)]  # Cycle through colors if more coefficients than colors
    label = f'w{i+1}'
    
    plt.hist(df[col_name], bins=50, alpha=0.8, color=color, edgecolor='black', 
             linewidth=0.5, label=label)

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mix Coefficients')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 20, 100, 200] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Saves figure to a folder named 'Figures'
os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
fig.savefig('../figures/zircon/mixing/dPy-mix_ct-2_ct-3_to_ct-9_age_distribution.svg')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('../figures/zircon/mixing/dPy-mix_ct-5_ct-6_to_ct-10_objective_function_distributions.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('../figures/zircon/mixing/dPy-mix_ct-5_ct-6_to_ct-10_distribution_comparisons.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('../figures/zircon/mixing/dPy-mix_ct-5_ct-6_to_ct-10_spatial_comparison.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
os.makedirs('../results/mixing_coefficients', exist_ok=True)
file_name = '../results/mixing_coefficients/dPy-mix_ct-2_ct-3_to_ct-9_results.xlsx'
dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                   obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                   bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                   doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                   mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                   worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
# Out:
# Workbook saved
