# %% [markdown]
# # DetritalPy Mixing code for the Mataquito River: Every Scenario

# %% [markdown]
# ## detritalPy-mix
# #### Glenn R. Sharman and Sam A. Johnstone
# #### Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty
# #### Version 0.1 (Beta)
# ##### Updated Feb 9, 2024
# ##### Requires detritalPy v1.4.0 or later
# ##### This is a Beta release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.
# ##### If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044)

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import os
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).
#
# Change parent and child list to see mixing results for CT-1 through CT-11

# %%
dataToLoad = ['../data/geochronology/zircon_upb/CT-1-11_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

""" 
Plug in the two / three parents that you want followed by all the children associated with all the parents. The options below are set up for easy use.
You will choose what parents you want and the associated child. Comment in/out whichever you want
"""
# Child options where parent list is CT-7, CT-1
#parent_list = ['CT-7', 'CT-1']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Child options where parent list is CT-5, CT-6
#parent_list = ['CT-5', 'CT-6']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Parent list options where Child is CT-2
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-2']

# Parent list options where Child is CT-9
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
parent_list = ['CT-2', 'CT-3']
child_list = ['CT-9']

# Three to one mixtures
    # Parent list options where Child is CT-2
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-2']

    # Parent list options where Child is CT-9
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-9']

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 2 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.18517279118094554
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Completed mixing children.
# Time elapsed: 0.033 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-9
# Best-fit vmax : 0.185
# Mixing coefficients
# --- CT-2 : 0.999
# --- CT-3 : 0.001

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 10000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-9 ( 1 of 1 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 7.528 minutes remaining
# 0.1 % completed, 0.006 minutes elapsed, 5.276 minutes remaining
# 0.2 % completed, 0.011 minutes elapsed, 5.118 minutes remaining
# 0.3 % completed, 0.016 minutes elapsed, 5.056 minutes remaining
# 0.4 % completed, 0.021 minutes elapsed, 5.041 minutes remaining
# 0.5 % completed, 0.026 minutes elapsed, 5.019 minutes remaining
# 0.6 % completed, 0.031 minutes elapsed, 5.015 minutes remaining
# 0.7 % completed, 0.036 minutes elapsed, 4.998 minutes remaining
# 0.8 % completed, 0.041 minutes elapsed, 4.98 minutes remaining
# 0.9 % completed, 0.046 minutes elapsed, 4.984 minutes remaining
# 1.0 % completed, 0.051 minutes elapsed, 4.974 minutes remaining
# 1.1 % completed, 0.056 minutes elapsed, 4.966 minutes remaining
# 1.2 % completed, 0.061 minutes elapsed, 4.961 minutes remaining
# 1.3 % completed, 0.066 minutes elapsed, 4.961 minutes remaining
# 23.0 % completed, 1.157 minutes elapsed, 3.871 minutes remaining
# 23.1 % completed, 1.162 minutes elapsed, 3.866 minutes remaining
# 23.2 % completed, 1.167 minutes elapsed, 3.861 minutes remaining
# 23.3 % completed, 1.172 minutes elapsed, 3.856 minutes remaining
# 23.4 % completed, 1.177 minutes elapsed, 3.851 minutes remaining
# 23.5 % completed, 1.182 minutes elapsed, 3.845 minutes remaining
# 23.6 % completed, 1.187 minutes elapsed, 3.84 minutes remaining
# 23.7 % completed, 1.192 minutes elapsed, 3.835 minutes remaining
# 23.8 % completed, 1.197 minutes elapsed, 3.83 minutes remaining
# 23.9 % completed, 1.202 minutes elapsed, 3.824 minutes remaining
# 24.0 % completed, 1.207 minutes elapsed, 3.82 minutes remaining
# 24.1 % completed, 1.212 minutes elapsed, 3.815 minutes remaining
# 24.2 % completed, 1.217 minutes elapsed, 3.81 minutes remaining
# 24.3 % completed, 1.222 minutes elapsed, 3.805 minutes remaining
# 24.4 % completed, 1.227 minutes elapsed, 3.8 minutes remaining
# 24.5 % completed, 1.232 minutes elapsed, 3.795 minutes remaining
# 24.6 % completed, 1.237 minutes elapsed, 3.789 minutes remaining
# 24.7 % completed, 1.242 minutes elapsed, 3.784 minutes remaining
# 24.8 % completed, 1.247 minutes elapsed, 3.779 minutes remaining
# 24.9 % completed, 1.252 minutes elapsed, 3.774 minutes remaining
# 25.0 % completed, 1.257 minutes elapsed, 3.769 minutes remaining
# 25.1 % completed, 1.262 minutes elapsed, 3.764 minutes remaining
# 25.2 % completed, 1.267 minutes elapsed, 3.759 minutes remaining
# 25.3 % completed, 1.272 minutes elapsed, 3.754 minutes remaining
# 25.4 % completed, 1.277 minutes elapsed, 3.749 minutes remaining
# 25.5 % completed, 1.282 minutes elapsed, 3.744 minutes remaining
# 25.6 % completed, 1.287 minutes elapsed, 3.739 minutes remaining
# 25.7 % completed, 1.292 minutes elapsed, 3.734 minutes remaining
# 25.8 % completed, 1.297 minutes elapsed, 3.729 minutes remaining
# 25.9 % completed, 1.302 minutes elapsed, 3.724 minutes remaining
# 26.0 % completed, 1.307 minutes elapsed, 3.719 minutes remaining
# 26.1 % completed, 1.312 minutes elapsed, 3.714 minutes remaining
# 26.2 % completed, 1.317 minutes elapsed, 3.708 minutes remaining
# 26.3 % completed, 1.322 minutes elapsed, 3.703 minutes remaining
# 26.4 % completed, 1.327 minutes elapsed, 3.698 minutes remaining
# 26.5 % completed, 1.332 minutes elapsed, 3.693 minutes remaining
# 26.6 % completed, 1.337 minutes elapsed, 3.688 minutes remaining
# 26.7 % completed, 1.342 minutes elapsed, 3.683 minutes remaining
# 26.8 % completed, 1.347 minutes elapsed, 3.678 minutes remaining
# 26.9 % completed, 1.352 minutes elapsed, 3.673 minutes remaining
# 27.0 % completed, 1.357 minutes elapsed, 3.668 minutes remaining
# 27.1 % completed, 1.362 minutes elapsed, 3.663 minutes remaining
# 27.2 % completed, 1.367 minutes elapsed, 3.658 minutes remaining
# 27.3 % completed, 1.372 minutes elapsed, 3.653 minutes remaining
# 27.4 % completed, 1.377 minutes elapsed, 3.648 minutes remaining
# 27.5 % completed, 1.382 minutes elapsed, 3.643 minutes remaining
# 27.6 % completed, 1.387 minutes elapsed, 3.638 minutes remaining
# 27.7 % completed, 1.392 minutes elapsed, 3.633 minutes remaining
# 27.8 % completed, 1.397 minutes elapsed, 3.628 minutes remaining
# 27.9 % completed, 1.402 minutes elapsed, 3.623 minutes remaining
# 28.0 % completed, 1.407 minutes elapsed, 3.618 minutes remaining
# 28.1 % completed, 1.412 minutes elapsed, 3.612 minutes remaining
# 28.2 % completed, 1.417 minutes elapsed, 3.607 minutes remaining
# 28.3 % completed, 1.422 minutes elapsed, 3.602 minutes remaining
# 28.4 % completed, 1.427 minutes elapsed, 3.597 minutes remaining
# 28.5 % completed, 1.432 minutes elapsed, 3.592 minutes remaining
# 28.6 % completed, 1.437 minutes elapsed, 3.587 minutes remaining
# 28.7 % completed, 1.443 minutes elapsed, 3.582 minutes remaining
# 28.8 % completed, 1.448 minutes elapsed, 3.578 minutes remaining
# 28.9 % completed, 1.453 minutes elapsed, 3.572 minutes remaining
# 29.0 % completed, 1.458 minutes elapsed, 3.567 minutes remaining
# 29.1 % completed, 1.462 minutes elapsed, 3.562 minutes remaining
# 29.2 % completed, 1.467 minutes elapsed, 3.557 minutes remaining
# 29.3 % completed, 1.472 minutes elapsed, 3.552 minutes remaining
# 29.4 % completed, 1.477 minutes elapsed, 3.547 minutes remaining
# 29.5 % completed, 1.482 minutes elapsed, 3.542 minutes remaining
# 29.6 % completed, 1.488 minutes elapsed, 3.537 minutes remaining
# 29.7 % completed, 1.493 minutes elapsed, 3.532 minutes remaining
# 29.8 % completed, 1.498 minutes elapsed, 3.527 minutes remaining
# 29.9 % completed, 1.503 minutes elapsed, 3.522 minutes remaining
# 30.0 % completed, 1.508 minutes elapsed, 3.517 minutes remaining
# 30.1 % completed, 1.513 minutes elapsed, 3.513 minutes remaining
# 30.2 % completed, 1.518 minutes elapsed, 3.508 minutes remaining
# 30.3 % completed, 1.524 minutes elapsed, 3.503 minutes remaining
# 30.4 % completed, 1.529 minutes elapsed, 3.499 minutes remaining
# 30.5 % completed, 1.534 minutes elapsed, 3.494 minutes remaining
# 30.6 % completed, 1.539 minutes elapsed, 3.489 minutes remaining
# 30.7 % completed, 1.544 minutes elapsed, 3.484 minutes remaining
# 30.8 % completed, 1.549 minutes elapsed, 3.479 minutes remaining
# 30.9 % completed, 1.554 minutes elapsed, 3.475 minutes remaining
# 31.0 % completed, 1.559 minutes elapsed, 3.469 minutes remaining
# 31.1 % completed, 1.564 minutes elapsed, 3.465 minutes remaining
# 31.2 % completed, 1.569 minutes elapsed, 3.46 minutes remaining
# 31.3 % completed, 1.574 minutes elapsed, 3.455 minutes remaining
# 31.4 % completed, 1.579 minutes elapsed, 3.45 minutes remaining
# 31.5 % completed, 1.585 minutes elapsed, 3.445 minutes remaining
# 31.6 % completed, 1.589 minutes elapsed, 3.439 minutes remaining
# 62.0 % completed, 3.15 minutes elapsed, 1.93 minutes remaining
# 62.1 % completed, 3.155 minutes elapsed, 1.925 minutes remaining
# 62.2 % completed, 3.16 minutes elapsed, 1.92 minutes remaining
# 62.3 % completed, 3.165 minutes elapsed, 1.915 minutes remaining
# 62.4 % completed, 3.17 minutes elapsed, 1.91 minutes remaining
# 62.5 % completed, 3.176 minutes elapsed, 1.905 minutes remaining
# 62.6 % completed, 3.181 minutes elapsed, 1.9 minutes remaining
# 62.7 % completed, 3.186 minutes elapsed, 1.895 minutes remaining
# 62.8 % completed, 3.191 minutes elapsed, 1.89 minutes remaining
# 62.9 % completed, 3.196 minutes elapsed, 1.885 minutes remaining
# 63.0 % completed, 3.201 minutes elapsed, 1.88 minutes remaining
# 63.1 % completed, 3.206 minutes elapsed, 1.875 minutes remaining
# 63.2 % completed, 3.212 minutes elapsed, 1.87 minutes remaining
# 63.3 % completed, 3.217 minutes elapsed, 1.865 minutes remaining
# 63.4 % completed, 3.222 minutes elapsed, 1.86 minutes remaining
# 63.5 % completed, 3.227 minutes elapsed, 1.855 minutes remaining
# 63.6 % completed, 3.232 minutes elapsed, 1.85 minutes remaining
# 63.7 % completed, 3.237 minutes elapsed, 1.844 minutes remaining
# 63.8 % completed, 3.242 minutes elapsed, 1.839 minutes remaining
# 63.9 % completed, 3.248 minutes elapsed, 1.834 minutes remaining
# 64.0 % completed, 3.253 minutes elapsed, 1.829 minutes remaining
# 64.1 % completed, 3.258 minutes elapsed, 1.824 minutes remaining
# 64.2 % completed, 3.263 minutes elapsed, 1.819 minutes remaining
# 64.3 % completed, 3.268 minutes elapsed, 1.814 minutes remaining
# 64.4 % completed, 3.273 minutes elapsed, 1.809 minutes remaining
# 64.5 % completed, 3.278 minutes elapsed, 1.804 minutes remaining
# 64.6 % completed, 3.284 minutes elapsed, 1.799 minutes remaining
# 64.7 % completed, 3.289 minutes elapsed, 1.794 minutes remaining
# 64.8 % completed, 3.294 minutes elapsed, 1.789 minutes remaining
# 64.9 % completed, 3.299 minutes elapsed, 1.784 minutes remaining
# 65.0 % completed, 3.304 minutes elapsed, 1.779 minutes remaining
# 65.1 % completed, 3.309 minutes elapsed, 1.774 minutes remaining
# 65.2 % completed, 3.314 minutes elapsed, 1.769 minutes remaining
# 65.3 % completed, 3.319 minutes elapsed, 1.764 minutes remaining
# 65.4 % completed, 3.324 minutes elapsed, 1.759 minutes remaining
# 65.5 % completed, 3.33 minutes elapsed, 1.753 minutes remaining
# 65.6 % completed, 3.335 minutes elapsed, 1.748 minutes remaining
# 65.7 % completed, 3.34 minutes elapsed, 1.743 minutes remaining
# 65.8 % completed, 3.345 minutes elapsed, 1.738 minutes remaining
# 65.9 % completed, 3.35 minutes elapsed, 1.733 minutes remaining
# 66.0 % completed, 3.355 minutes elapsed, 1.728 minutes remaining
# 66.1 % completed, 3.36 minutes elapsed, 1.723 minutes remaining
# 66.2 % completed, 3.365 minutes elapsed, 1.718 minutes remaining
# 66.3 % completed, 3.37 minutes elapsed, 1.713 minutes remaining
# 70.7 % completed, 3.598 minutes elapsed, 1.491 minutes remaining
# 70.8 % completed, 3.603 minutes elapsed, 1.486 minutes remaining
# 70.9 % completed, 3.608 minutes elapsed, 1.481 minutes remaining
# 71.0 % completed, 3.613 minutes elapsed, 1.475 minutes remaining
# 71.1 % completed, 3.618 minutes elapsed, 1.47 minutes remaining
# 71.2 % completed, 3.623 minutes elapsed, 1.465 minutes remaining
# 71.3 % completed, 3.628 minutes elapsed, 1.46 minutes remaining
# 71.4 % completed, 3.633 minutes elapsed, 1.455 minutes remaining
# 71.5 % completed, 3.638 minutes elapsed, 1.45 minutes remaining
# 71.6 % completed, 3.643 minutes elapsed, 1.445 minutes remaining
# 71.7 % completed, 3.649 minutes elapsed, 1.44 minutes remaining
# 71.8 % completed, 3.653 minutes elapsed, 1.435 minutes remaining
# 71.9 % completed, 3.659 minutes elapsed, 1.43 minutes remaining
# 72.0 % completed, 3.664 minutes elapsed, 1.425 minutes remaining
# 72.1 % completed, 3.669 minutes elapsed, 1.419 minutes remaining
# 72.2 % completed, 3.674 minutes elapsed, 1.414 minutes remaining
# 72.3 % completed, 3.679 minutes elapsed, 1.409 minutes remaining
# 72.4 % completed, 3.684 minutes elapsed, 1.404 minutes remaining
# 72.5 % completed, 3.689 minutes elapsed, 1.399 minutes remaining
# 72.6 % completed, 3.694 minutes elapsed, 1.394 minutes remaining
# 72.7 % completed, 3.699 minutes elapsed, 1.389 minutes remaining
# 72.8 % completed, 3.704 minutes elapsed, 1.384 minutes remaining
# 72.9 % completed, 3.709 minutes elapsed, 1.379 minutes remaining
# 73.0 % completed, 3.714 minutes elapsed, 1.374 minutes remaining
# 73.1 % completed, 3.72 minutes elapsed, 1.369 minutes remaining
# 73.2 % completed, 3.725 minutes elapsed, 1.363 minutes remaining
# 73.3 % completed, 3.73 minutes elapsed, 1.358 minutes remaining
# 73.4 % completed, 3.735 minutes elapsed, 1.353 minutes remaining
# 73.5 % completed, 3.74 minutes elapsed, 1.348 minutes remaining
# 73.6 % completed, 3.745 minutes elapsed, 1.343 minutes remaining
# 73.7 % completed, 3.75 minutes elapsed, 1.338 minutes remaining
# 73.8 % completed, 3.755 minutes elapsed, 1.333 minutes remaining
# 73.9 % completed, 3.76 minutes elapsed, 1.328 minutes remaining
# ...
# 75.4 % completed, 3.836 minutes elapsed, 1.252 minutes remaining
# 75.5 % completed, 3.842 minutes elapsed, 1.246 minutes remaining
# 75.6 % completed, 3.847 minutes elapsed, 1.241 minutes remaining
# 75.7 % completed, 3.852 minutes elapsed, 1.236 minutes remaining
# 75.8 % completed, 3.857 minutes elapsed, 1.231 minutes remaining
# 75.9 % completed, 3.862 minutes elapsed, 1.226 minutes remaining
# 76.0 % completed, 3.867 minutes elapsed, 1.221 minutes remaining
# 76.1 % completed, 3.872 minutes elapsed, 1.216 minutes remaining
# 76.2 % completed, 3.877 minutes elapsed, 1.211 minutes remaining
# 76.3 % completed, 3.882 minutes elapsed, 1.206 minutes remaining
# 85.1 % completed, 4.329 minutes elapsed, 0.758 minutes remaining
# 85.2 % completed, 4.334 minutes elapsed, 0.753 minutes remaining
# 85.3 % completed, 4.339 minutes elapsed, 0.748 minutes remaining
# 85.4 % completed, 4.344 minutes elapsed, 0.743 minutes remaining
# 85.5 % completed, 4.349 minutes elapsed, 0.738 minutes remaining
# 85.6 % completed, 4.355 minutes elapsed, 0.732 minutes remaining
# 85.7 % completed, 4.36 minutes elapsed, 0.727 minutes remaining
# 85.8 % completed, 4.365 minutes elapsed, 0.722 minutes remaining
# 85.9 % completed, 4.37 minutes elapsed, 0.717 minutes remaining
# 86.0 % completed, 4.375 minutes elapsed, 0.712 minutes remaining
# 86.1 % completed, 4.38 minutes elapsed, 0.707 minutes remaining
# 86.2 % completed, 4.385 minutes elapsed, 0.702 minutes remaining
# 86.3 % completed, 4.39 minutes elapsed, 0.697 minutes remaining
# 86.4 % completed, 4.395 minutes elapsed, 0.692 minutes remaining
# 86.5 % completed, 4.4 minutes elapsed, 0.687 minutes remaining
# 86.6 % completed, 4.405 minutes elapsed, 0.682 minutes remaining
# 86.7 % completed, 4.411 minutes elapsed, 0.677 minutes remaining
# 86.8 % completed, 4.416 minutes elapsed, 0.671 minutes remaining
# 86.9 % completed, 4.421 minutes elapsed, 0.666 minutes remaining
# 87.0 % completed, 4.426 minutes elapsed, 0.661 minutes remaining
# 87.1 % completed, 4.431 minutes elapsed, 0.656 minutes remaining
# 87.2 % completed, 4.437 minutes elapsed, 0.651 minutes remaining
# 87.3 % completed, 4.442 minutes elapsed, 0.646 minutes remaining
# 87.4 % completed, 4.447 minutes elapsed, 0.641 minutes remaining
# 87.5 % completed, 4.452 minutes elapsed, 0.636 minutes remaining
# 87.6 % completed, 4.457 minutes elapsed, 0.631 minutes remaining
# 87.7 % completed, 4.462 minutes elapsed, 0.626 minutes remaining
# 87.8 % completed, 4.467 minutes elapsed, 0.621 minutes remaining
# 87.9 % completed, 4.472 minutes elapsed, 0.616 minutes remaining
# 88.0 % completed, 4.477 minutes elapsed, 0.61 minutes remaining
# 88.1 % completed, 4.482 minutes elapsed, 0.605 minutes remaining
# 88.2 % completed, 4.488 minutes elapsed, 0.6 minutes remaining
# 88.3 % completed, 4.493 minutes elapsed, 0.595 minutes remaining
# 88.4 % completed, 4.498 minutes elapsed, 0.59 minutes remaining
# 88.5 % completed, 4.503 minutes elapsed, 0.585 minutes remaining
# 88.6 % completed, 4.508 minutes elapsed, 0.58 minutes remaining
# 88.7 % completed, 4.513 minutes elapsed, 0.575 minutes remaining
# 88.8 % completed, 4.518 minutes elapsed, 0.57 minutes remaining
# 88.9 % completed, 4.523 minutes elapsed, 0.565 minutes remaining
# 89.0 % completed, 4.528 minutes elapsed, 0.56 minutes remaining
# 89.1 % completed, 4.533 minutes elapsed, 0.555 minutes remaining
# 89.2 % completed, 4.538 minutes elapsed, 0.549 minutes remaining
# 89.3 % completed, 4.544 minutes elapsed, 0.544 minutes remaining
# 89.4 % completed, 4.549 minutes elapsed, 0.539 minutes remaining
# 93.8 % completed, 4.855 minutes elapsed, 0.321 minutes remaining
# 93.9 % completed, 4.86 minutes elapsed, 0.316 minutes remaining
# 94.0 % completed, 4.866 minutes elapsed, 0.311 minutes remaining
# 94.1 % completed, 4.871 minutes elapsed, 0.305 minutes remaining
# 94.2 % completed, 4.876 minutes elapsed, 0.3 minutes remaining
# 94.3 % completed, 4.881 minutes elapsed, 0.295 minutes remaining
# 94.4 % completed, 4.886 minutes elapsed, 0.29 minutes remaining
# 94.5 % completed, 4.892 minutes elapsed, 0.285 minutes remaining
# 94.6 % completed, 4.897 minutes elapsed, 0.279 minutes remaining
# 94.7 % completed, 4.902 minutes elapsed, 0.274 minutes remaining
# 94.8 % completed, 4.907 minutes elapsed, 0.269 minutes remaining
# 94.9 % completed, 4.913 minutes elapsed, 0.264 minutes remaining
# 95.0 % completed, 4.918 minutes elapsed, 0.259 minutes remaining
# 95.1 % completed, 4.923 minutes elapsed, 0.254 minutes remaining
# 95.2 % completed, 4.928 minutes elapsed, 0.248 minutes remaining
# 95.3 % completed, 4.934 minutes elapsed, 0.243 minutes remaining
# 95.4 % completed, 4.939 minutes elapsed, 0.238 minutes remaining
# 95.5 % completed, 4.944 minutes elapsed, 0.233 minutes remaining
# 95.6 % completed, 4.95 minutes elapsed, 0.228 minutes remaining
# 95.7 % completed, 4.955 minutes elapsed, 0.223 minutes remaining
# 95.8 % completed, 4.96 minutes elapsed, 0.217 minutes remaining
# 95.9 % completed, 4.965 minutes elapsed, 0.212 minutes remaining
# 96.0 % completed, 4.971 minutes elapsed, 0.207 minutes remaining
# 96.1 % completed, 4.976 minutes elapsed, 0.202 minutes remaining
# 96.2 % completed, 4.981 minutes elapsed, 0.197 minutes remaining
# 96.3 % completed, 4.986 minutes elapsed, 0.192 minutes remaining
# 96.4 % completed, 4.991 minutes elapsed, 0.186 minutes remaining
# 96.5 % completed, 4.996 minutes elapsed, 0.181 minutes remaining
# 96.6 % completed, 5.002 minutes elapsed, 0.176 minutes remaining
# 96.7 % completed, 5.007 minutes elapsed, 0.171 minutes remaining
# 96.8 % completed, 5.012 minutes elapsed, 0.166 minutes remaining
# 96.9 % completed, 5.017 minutes elapsed, 0.16 minutes remaining
# 97.0 % completed, 5.022 minutes elapsed, 0.155 minutes remaining
# 97.1 % completed, 5.027 minutes elapsed, 0.15 minutes remaining
# 97.2 % completed, 5.032 minutes elapsed, 0.145 minutes remaining
# 97.3 % completed, 5.037 minutes elapsed, 0.14 minutes remaining
# 97.4 % completed, 5.043 minutes elapsed, 0.135 minutes remaining
# 97.5 % completed, 5.048 minutes elapsed, 0.129 minutes remaining
# 97.6 % completed, 5.053 minutes elapsed, 0.124 minutes remaining
# 97.7 % completed, 5.058 minutes elapsed, 0.119 minutes remaining
# 97.8 % completed, 5.063 minutes elapsed, 0.114 minutes remaining
# 97.9 % completed, 5.068 minutes elapsed, 0.109 minutes remaining
# 98.0 % completed, 5.073 minutes elapsed, 0.104 minutes remaining
# 98.1 % completed, 5.078 minutes elapsed, 0.098 minutes remaining
# 98.2 % completed, 5.083 minutes elapsed, 0.093 minutes remaining
# 98.3 % completed, 5.088 minutes elapsed, 0.088 minutes remaining
# 98.4 % completed, 5.093 minutes elapsed, 0.083 minutes remaining
# 98.5 % completed, 5.098 minutes elapsed, 0.078 minutes remaining
# 98.6 % completed, 5.104 minutes elapsed, 0.072 minutes remaining
# 98.7 % completed, 5.109 minutes elapsed, 0.067 minutes remaining
# 98.8 % completed, 5.114 minutes elapsed, 0.062 minutes remaining
# 98.9 % completed, 5.119 minutes elapsed, 0.057 minutes remaining
# 99.0 % completed, 5.124 minutes elapsed, 0.052 minutes remaining
# 99.1 % completed, 5.129 minutes elapsed, 0.047 minutes remaining
# 99.2 % completed, 5.134 minutes elapsed, 0.041 minutes remaining
# 99.3 % completed, 5.139 minutes elapsed, 0.036 minutes remaining
# 99.4 % completed, 5.144 minutes elapsed, 0.031 minutes remaining
# 99.5 % completed, 5.149 minutes elapsed, 0.026 minutes remaining
# 99.6 % completed, 5.154 minutes elapsed, 0.021 minutes remaining
# 99.7 % completed, 5.16 minutes elapsed, 0.016 minutes remaining
# 99.8 % completed, 5.165 minutes elapsed, 0.01 minutes remaining
# 99.9 % completed, 5.17 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %%
#print(mix_coeffs_all)

# %%
print(f"Number of items: {len(mix_coeffs_all[0])}")
print(f"Array shape: {mix_coeffs_all[0].shape}")
# Out:
# Number of items: 10000
# Array shape: (10000, 2)

# %% [markdown]
# ### Export csv file of mix_coeffs_all for use in the zircon fertility analysis

# %%
# Converting the mix_coeffs_all to a 2D array so that we can run all 10,000 pairs of w1 and w2 through to understand the
# distribution through the bootstraping analyses. 
try:
    # Convert list to NumPy array
    array = np.array(mix_coeffs_all)
    # Flatten the array
    flattened_array = array.reshape(-1, array.shape[-1])
    # Determine column names based on the number of coefficients
    num_coeffs = flattened_array.shape[1]
    if num_coeffs == 2:
        column_names = ['Column1', 'Column2']
    elif num_coeffs == 3:
        column_names = ['Column1', 'Column2', 'Column3']
    else:
        # Fallback for other numbers of coefficients
        column_names = [f'Column{i+1}' for i in range(num_coeffs)]
    # Convert to DataFrame
    df = pd.DataFrame(flattened_array, columns=column_names)
    # Save to CSV in a "Spreadsheets" folder
    folder_path = "../results/mixing_coefficients"
    # Change name to current mixture
    filename = "mix_coeffs_all_ct-2_ct-3_to_ct-9.csv"
    # Create folder if it doesn't exist
    os.makedirs(folder_path, exist_ok=True)
    # Create full path and save
    full_path = os.path.join(folder_path, filename)
    df.to_csv(full_path, index=False)
    print("Saved")
    
except Exception as e:
    print(f"Not saved: {e}")
    # Optional: Print array shape for debugging
    if 'array' in locals():
        print(f"Array shape: {array.shape}")
    if 'flattened_array' in locals():
        print(f"Flattened array shape: {flattened_array.shape}")
# Out:
# Saved

# %%
# Plot histograms of all coefficients on same plot to visualize the distributions
plt.figure(figsize=(10, 6))

# Define colors for up to 6 coefficients (extend as needed)
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown']

# Get the number of coefficient columns
num_coeffs = len([col for col in df.columns if col.startswith('Column')])

# Plot histogram for each coefficient
for i in range(num_coeffs):
    col_name = f'Column{i+1}'
    color = colors[i % len(colors)]  # Cycle through colors if more coefficients than colors
    label = f'w{i+1}'
    
    plt.hist(df[col_name], bins=50, alpha=0.8, color=color, edgecolor='black', 
             linewidth=0.5, label=label)

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mix Coefficients')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 20, 100, 200] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Saves figure to a folder named 'Figures'
os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
fig.savefig('../figures/zircon/mixing/dPy-mix_ct-2_ct-3_to_ct-9_age_distribution.svg')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('../figures/zircon/mixing/dPy-mix_ct-5_ct-6_to_ct-10_objective_function_distributions.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('../figures/zircon/mixing/dPy-mix_ct-5_ct-6_to_ct-10_distribution_comparisons.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('../figures/zircon/mixing/dPy-mix_ct-5_ct-6_to_ct-10_spatial_comparison.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
os.makedirs('../results/mixing_coefficients', exist_ok=True)
file_name = '../results/mixing_coefficients/dPy-mix_ct-2_ct-3_to_ct-9_results.xlsx'
dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                   obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                   bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                   doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                   mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                   worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
# Out:
# Workbook saved
